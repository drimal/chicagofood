# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
weather = pd.read_csv('../data/raw/weather.csv',
                      index_col='DATE',
                      parse_dates=['DATE'])
weather = weather[weather['STATION'] == "USW00094846"]
print(weather.head())
print(weather.shape)
# Out:
#                 STATION                                        NAME  TAVG  \
# DATE
# 2016-12-25  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  33.0
# 2016-12-26  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  45.0
# 2016-12-27  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  28.0
# 2016-12-28  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  30.0
# 2016-12-29  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US  34.0
#
#             TMAX  TMIN  TOBS
# DATE
# 2016-12-25  39.0  32.0   NaN
# 2016-12-26  54.0  28.0   NaN
# 2016-12-27  28.0  19.0   NaN
# 2016-12-28  45.0  19.0   NaN
# 2016-12-29  35.0  30.0   NaN
# (924, 6)

# %%
plt.figure(figsize=(12, 8))
weather['TMAX'].plot()
weather['TMAXAVG'] = weather['TMAX'].rolling(window=3, min_periods=1).mean()
#weather = weather.set_index('DATE')
weather['TMAXAVG'].plot()
weather.to_csv('../data/processed/weather_data_processed.csv')
